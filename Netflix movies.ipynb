# %% [markdown]
# Top 100 Netflix Movies

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading Dataset:

# %%
netflix = pd.read_csv(r"C:\Users\Radhika K J\Documents\100 Best Movies on Netflix.csv")

# %%
netflix
# Out:
#     Rank                      Movie Title  Year  Score             Director  \
# 0      1                        His House  2020    100          Remi Weekes
# 1      2         How to Train Your Dragon  2010     99  Christopher Sanders
# 2      3       The Forty-Year-Old Version  2020     99          Radha Blank
# 3      4                 Under the Shadow  2016     99         Babak Anvari
# 4      5  Monty Python and the Holy Grail  1975     98        Terry Gilliam
# ..   ...                              ...   ...    ...                  ...
# 95    96     Fear Street Part Three: 1666  2021     88         Leigh Janiak
# 96    97                    Donnie Brasco  1997     88          Mike Newell
# 97    98                        Inception  2010     87    Christopher Nolan
# 98    99                  American Beauty  1999     87           Sam Mendes
# 99   100                    Kung Fu Panda  2008     87       John Stevenson
#
#                                                  Cast  \
# ...

# %% [markdown]
# Data Overview

# %%
netflix.head(5) ##display first five rows in the dataset
# Out:
#    Rank                      Movie Title  Year  Score             Director  \
# 0     1                        His House  2020    100          Remi Weekes
# 1     2         How to Train Your Dragon  2010     99  Christopher Sanders
# 2     3       The Forty-Year-Old Version  2020     99          Radha Blank
# 3     4                 Under the Shadow  2016     99         Babak Anvari
# 4     5  Monty Python and the Holy Grail  1975     98        Terry Gilliam
#
#                                                 Cast  \
# 0  Wunmi Mosaku, Sope Dirisu, Matt Smith, Cornell...
# 1  Jay Baruchel, Gerard Butler, America Ferrera, ...
# 2  Welker White, Reed Birney, Radha Blank, Peter Kim
# 3  Narges Rashidi, Avin Manshadi, Bobby Naderi, R...
# 4  Graham Chapman, John Cleese, Terry Gilliam, Er...
#
#                                    Critics Consensus
# 0  Featuring genuine scares through every corrido...
# 1  Boasting dazzling animation, a script with sur...
# ...

# %%
netflix.columns ##display all columns in the dataset
# Out:
# Index(['Rank', 'Movie Title', 'Year', 'Score', 'Director', 'Cast',
#        'Critics Consensus'],
#       dtype='object')

# %%
netflix.shape ##display rows and column in the dataset
# Out:
# (100, 7)

# %%
netflix.info()  ##display all information in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               100 non-null    int64
#  1   Movie Title        100 non-null    object
#  2   Year               100 non-null    int64
#  3   Score              100 non-null    int64
#  4   Director           100 non-null    object
#  5   Cast               100 non-null    object
#  6   Critics Consensus  100 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 5.6+ KB

# %%
netflix.describe() ##display all continuous numerical columns using statistical functions
# Out:
#              Rank         Year       Score
# count  100.000000   100.000000  100.000000
# mean    50.500000  2011.540000   92.520000
# std     29.011492    12.971157    3.063239
# min      1.000000  1960.000000   87.000000
# 25%     25.750000  2009.750000   90.000000
# 50%     50.500000  2017.000000   92.000000
# 75%     75.250000  2019.000000   95.000000
# max    100.000000  2022.000000  100.000000

# %%
netflix.isna() ##display all null values in the dataset
# Out:
#      Rank  Movie Title   Year  Score  Director   Cast  Critics Consensus
# 0   False        False  False  False     False  False              False
# 1   False        False  False  False     False  False              False
# 2   False        False  False  False     False  False              False
# 3   False        False  False  False     False  False              False
# 4   False        False  False  False     False  False              False
# ..    ...          ...    ...    ...       ...    ...                ...
# 95  False        False  False  False     False  False              False
# 96  False        False  False  False     False  False              False
# 97  False        False  False  False     False  False              False
# 98  False        False  False  False     False  False              False
# 99  False        False  False  False     False  False              False
#
# [100 rows x 7 columns]

# %%
netflix.notna() ##display not null values in the dataset
# Out:
#     Rank  Movie Title  Year  Score  Director  Cast  Critics Consensus
# 0   True         True  True   True      True  True               True
# 1   True         True  True   True      True  True               True
# 2   True         True  True   True      True  True               True
# 3   True         True  True   True      True  True               True
# 4   True         True  True   True      True  True               True
# ..   ...          ...   ...    ...       ...   ...                ...
# 95  True         True  True   True      True  True               True
# 96  True         True  True   True      True  True               True
# 97  True         True  True   True      True  True               True
# 98  True         True  True   True      True  True               True
# 99  True         True  True   True      True  True               True
#
# [100 rows x 7 columns]

# %%
netflix.tail()   ##display last rows  in the dataset
# Out:
#     Rank                   Movie Title  Year  Score           Director  \
# 95    96  Fear Street Part Three: 1666  2021     88       Leigh Janiak
# 96    97                 Donnie Brasco  1997     88        Mike Newell
# 97    98                     Inception  2010     87  Christopher Nolan
# 98    99               American Beauty  1999     87         Sam Mendes
# 99   100                 Kung Fu Panda  2008     87     John Stevenson
#
#                                                  Cast  \
# 95  Kiana Madeira, Ashley Zukerman, Gillian Jacobs...
# 96  Al Pacino, Johnny Depp, Michael Madsen, Bruno ...
# 97  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 98  Kevin Spacey, Annette Bening, Thora Birch, Wes...
# 99  Jack Black, Angelina Jolie, Jackie Chan, David...
#
#                                     Critics Consensus
# 95  Fear Street Part Three: 1666 sends the slasher...
# 96  A stark, nuanced portrait of life in organized...
# ...

# %% [markdown]
# Data Analysis using Statistical values

# %% [markdown]
# Import Statistical Libraries

# %%
import statistics as stat
from statsmodels.stats.weightstats import ztest

# %% [markdown]
# Measures of Central Tendency and dispersion

# %% [markdown]
# Finding Statistical values for netflix movie Scores

# %%
stat.mean(netflix['Score'])
# Out:
# 92.52

# %%
stat.variance(netflix['Score'])
# Out:
# 9.383434343434343

# %%
stat.median(netflix['Score'])
# Out:
# 92.0

# %%
stat.mode(netflix['Score'])
# Out:
# 91

# %%
stat.stdev(netflix['Score'])
# Out:
# 3.0632391913519164

# %% [markdown]
# Z test between Rank and Score

# %%
z_stat,p_val=ztest(netflix['Rank'],netflix['Score'],value=0)
p_val
# Out:
# 4.89420880896117e-47

# %%
if p_val<0.05:
    print('Reject Null Hypothesis')
else:
    print('Accept Null Hypothesis')
# Out:
# Reject Null Hypothesis

# %% [markdown]
# Exploratory Data Analysis

# %%
plt.figure(figsize=(21,20))
plt.bar(netflix['Year'],netflix['Movie Title'])
plt.title('Top 100 Netflix Movies Released Time')
plt.xlabel('Year')
plt.ylabel('Movie Title')
plt.show()

# %%
sns.barplot(x=netflix['Score'],y=netflix['Year'],palette='PiYG',ci=None)
plt.title("Top 100 Netflix Movie Scores")
plt.show()
# Out:
# C:\Users\Radhika K J\AppData\Local\Temp\ipykernel_130904\635414771.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=netflix['Score'],y=netflix['Year'],palette='PiYG',ci=None)

# %% [markdown]
# Correlation matrix for the dataset Netflix

# %%
corr_matrix = netflix.corr()
sns.heatmap(corr_matrix,annot=True,cmap="PiYG")
# Out:
# C:\Users\Radhika K J\AppData\Local\Temp\ipykernel_130904\3094646146.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = netflix.corr()
# <Axes: >
